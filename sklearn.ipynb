# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('data\\FinalData.csv')
df
# Out:
#       Homework  Project  Quiz   Exam    Total      Final Grade
# 0    98.333333     95.0  97.5  100.0  98.5000  98.934091     A
# 1    81.166667      0.0  95.0   96.0  79.1750  79.271818    C+
# 2    80.333333      0.0  97.5   90.0  76.5500  40.508182     F
# 3    70.833333     40.0  73.0   60.0  61.2250  53.681818     F
# 4    86.250000     90.0  86.0   90.0  88.6375  88.502273    B+
# ..         ...      ...   ...    ...      ...        ...   ...
# 145  80.833333     30.0  65.5   77.5  68.4750  70.512879     C
# 146  82.083333     85.0  72.0   41.0  59.9625  49.224242     F
# 147  87.500000     80.0  83.0   72.0  77.7250  62.769697     D
# 148  90.000000     90.0  93.0   90.5  90.8500  92.381970     A
# 149  87.500000     90.0  84.5   77.0  82.0250  69.924242     C
#
# [150 rows x 7 columns]

# %%
x = df.drop(columns=['Total', 'Final', 'Grade'])
x
# Out:
#       Homework  Project  Quiz   Exam
# 0    98.333333     95.0  97.5  100.0
# 1    81.166667      0.0  95.0   96.0
# 2    80.333333      0.0  97.5   90.0
# 3    70.833333     40.0  73.0   60.0
# 4    86.250000     90.0  86.0   90.0
# ..         ...      ...   ...    ...
# 145  80.833333     30.0  65.5   77.5
# 146  82.083333     85.0  72.0   41.0
# 147  87.500000     80.0  83.0   72.0
# 148  90.000000     90.0  93.0   90.5
# 149  87.500000     90.0  84.5   77.0
#
# [150 rows x 4 columns]

# %%
y = df['Final']
y
# Out:
# 0      98.934091
# 1      79.271818
# 2      40.508182
# 3      53.681818
# 4      88.502273
#          ...
# 145    70.512879
# 146    49.224242
# 147    62.769697
# 148    92.381970
# 149    69.924242
# Name: Final, Length: 150, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

lr = linear_model.LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr.intercept_
# Out:
# -11.61735314996676

# %%
lr.coef_
# Out:
# array([0.116398  , 0.25380786, 0.40218859, 0.32543154])

# %%
y_pred_train = lr.predict(x_train)
y_pred_train
# Out:
# array([86.32425418, 71.62587702, 60.61131732,  5.27456743, 63.26621756,
#        76.8179215 , 91.19980269, 70.92086833, 95.69673743, 84.6603004 ,
#        84.6603004 , 31.62343345, 91.2827384 , 82.45294765, 92.99361813,
#        29.31049368, 75.05726734, 73.47238544, 67.93485916, 80.45334285,
#        76.28497129, 91.2827384 , 64.9535797 , 68.61668173, 80.88953682,
#        79.06602292, 70.91534066, 90.27573812, 64.18984875, 64.9535797 ,
#        61.00715916, 88.55626658, 65.6813735 , 80.23139743, 88.55626658,
#        83.81403471, 63.25474539, 86.00341748, 59.13043343, 72.6210952 ,
#        77.5516172 , 94.08294427, 52.6042761 , 45.82604208, 67.03120041,
#        45.82604208, 71.32836102, 90.27573812, 92.03335671, 59.13043343,
#        73.71445377, 60.18558832, 85.83969283, 50.33544943, 67.03120041,
#        55.66547834, 94.29091531, 44.64728776, 76.019723  , 86.32425418,
#        88.36507204, 68.9958375 , 83.52111354, 66.23551136, 56.44784554,
#        63.26621756, 63.14267782, 91.19980269, 92.99361813, 64.18984875,
#        61.00715916, 92.73345513, 75.68482368, 92.03335671, 94.08294427,
#        61.81092172, 76.8179215 , 79.06602292, 56.97001722, 76.0117064 ,
#        89.33518799, 95.03013335, 75.88696958, 45.61488973, 68.9958375 ,
#        73.71445377, 91.86125648, 52.79820468, 92.33126654, 67.27962745,
#        95.03013335,  5.27456743, 76.0117064 , 82.45294765, 92.73345513,
#        61.04818817, 91.86125648, 70.92086833, 80.45334285,  7.00634211,
#        63.14267782, 78.68730891, 86.04022418, 75.68482368, 68.61668173])

# %%
plt.scatter(y_train, y_pred_train)
plt.plot([0, 100], [0, 100], color='r')
plt.xlabel('Actual Final')
plt.ylabel('Predicted Final')
plt.show()

# %%
r2_score(y_train, y_pred_train)
# Out:
# 0.8276893733919757

# %%
y_pred_test = lr.predict(x_test)

plt.scatter(y_test, y_pred_test)
plt.plot([0, 100], [0, 100], color='r')
plt.xlabel('Actual Final')
plt.ylabel('Predicted Final')
plt.show()

# %%
r2_score(y_test, y_pred_test)
# Out:
# 0.8969705921320689
