# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv('data//FinalData.csv')
data
# Out:
#       Homework  Project  Quiz   Exam      Final Grade
# 0    19.666667       95  97.5  100.0  98.934091     A
# 1    16.233333        0  95.0   96.0  79.271818    C+
# 2    16.066667        0  97.5   90.0  40.508182     F
# 3    14.166667       40  73.0   60.0  53.681818     F
# 4    17.250000       90  86.0   90.0  88.502273    B+
# ..         ...      ...   ...    ...        ...   ...
# 145  16.166667       30  65.5   77.5  70.512879     C
# 146  16.416667       85  72.0   41.0  49.224242     F
# 147  17.500000       80  83.0   72.0  62.769697     D
# 148  18.000000       90  93.0   90.5  92.381970     A
# 149  17.500000       90  84.5   77.0  69.924242     C
#
# [150 rows x 6 columns]

# %%
data_features = ['Homework', 'Project', 'Quiz', 'Exam']
X = data[data_features]
y = data.Final

plt.subplot(2, 2 , 1)
plt.scatter(X['Homework'], y)
plt.subplot(2, 2, 2)
plt.scatter(X['Project'], y)
plt.subplot(2, 2, 3)
plt.scatter(X['Quiz'], y)
plt.subplot(2, 2, 4)
plt.scatter(X['Exam'], y)
