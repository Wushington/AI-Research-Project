# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv('data//FinalData.csv')
data
# Out:
#       Homework  Project  Quiz   Exam    Total      Final Grade
# 0    98.333333       95  97.5  100.0  98.5000  98.934091     A
# 1    81.166667        0  95.0   96.0  79.1750  79.271818    C+
# 2    80.333333        0  97.5   90.0  76.5500  40.508182     F
# 3    70.833333       40  73.0   60.0  61.2250  53.681818     F
# 4    86.250000       90  86.0   90.0  88.6375  88.502273    B+
# ..         ...      ...   ...    ...      ...        ...   ...
# 145  80.833333       30  65.5   77.5  68.4750  70.512879     C
# 146  82.083333       85  72.0   41.0  59.9625  49.224242     F
# 147  87.500000       80  83.0   72.0  77.7250  62.769697     D
# 148  90.000000       90  93.0   90.5  90.8500  92.381970     A
# 149  87.500000       90  84.5   77.0  82.0250  69.924242     C
#
# [150 rows x 7 columns]

# %%
data_features = ['Homework', 'Project', 'Quiz', 'Exam', 'Total']
X = data[data_features]
y = data.Final

plt.subplot(3, 2 , 1)
plt.scatter(X['Homework'], y)
plt.subplot(3, 2, 2)
plt.scatter(X['Project'], y)
plt.subplot(3, 2, 3)
plt.scatter(X['Quiz'], y)
plt.subplot(3, 2, 4)
plt.scatter(X['Exam'], y)
plt.subplot(3, 2, 5)
plt.scatter(X['Total'], y)
