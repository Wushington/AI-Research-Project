# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv('data//FinalData.csv')
data
# Out:
# Running cells with 'Python 3.10.11' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.

# %%
data_features = ['Homework', 'Project', 'Quiz', 'Exam', 'Total']
X = data[data_features]
y = data.Final

plt.subplot(2, 2 , 1)
plt.scatter(X['Homework'], y)
plt.subplot(2, 2, 2)
plt.scatter(X['Project'], y)
plt.subplot(2, 2, 3)
plt.scatter(X['Quiz'], y)
plt.subplot(2, 2, 4)
plt.scatter(X['Exam'], y)
plt.show()

# %%
plt.scatter(X['Total'], y)
plt.xlabel('Predicted Final Grade')
plt.ylabel('Actual Final Grade')
plt.title('Predicted vs Actual Final Grade')
plt.show()
